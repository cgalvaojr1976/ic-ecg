# %%
import wfdb
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import signal as sig

# %%
pd.options.mode.chained_assignment = None

diretorio = '/home/matheus/Documentos/Facul/IC/ECG_classification/data/'
base = 'WFDB_ChapmanShaoxing'
problemas = 0

fields = [] # Campos dos fields
nomes = [] # Nome dos files

# %%
# Caminhar pelo diretório escolhido
for root, dirs, files in os.walk(diretorio+base, topdown=False):
    for name in files:
        temp = name.split('.')
        if len(temp)==2:
            if name.split('.')[1] == 'hea':
                arquivo = os.path.join(root, temp[0])
                try:
                    # Leitura dos fields e dos records
                    # Não é necessário a leitura dos recors agora
                    record, field = wfdb.rdsamp(arquivo, channels=[1]) 
                    # Colocar nomes dos arquivos na lista de nomes
                    nomes.append(name.split('.')[0])
                    fields.append(field)
                except:
                    problemas += 1
print(problemas)
# Out:
# 0

# %%
# Criar tabela com os fields separados
for y in range(len(fields)):
    for x in range(len(fields[y]['comments'])):
        # Transformar os comentários em apenas os números
        fields[y][fields[y]['comments'][x].split(": ")[0]] = fields[y]['comments'][x].split(": ")[1]

df = pd.DataFrame(fields)
df['arquivos'] = nomes
df['base'] = base
df = df.drop('comments', 1)
# Out:
# /tmp/ipykernel_19695/3182171253.py:10: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df = df.drop('comments', 1)

# %%
# Substituir as linhas com mais de um diagnóstico
for x in range(len(df)):
    # Caso haja mais de um diagnóstico
    if len(df.loc[x]['Dx'].split(',')) > 1:
        valores = df.loc[x]['Dx'].split(',')
        # Criar lista de valores para substituírem
        lista = [df.loc[x] for y in range(len(valores))]
        # Modificar a lista com cada diagnóstico correto
        for y in range(len(lista)):
            lista[y]['Dx'] = valores[y]
            # Colocar lista na data frame
            df = df.append(lista[y])

# %%
df = df.reset_index()

# %%
df
# Out:
#        index   fs  sig_len  n_sig base_date base_time units sig_name Age  \
# 0          0  500     5000      1      None  00:00:24  [mV]     [II]  88
# 1          1  500     5000      1      None  00:00:24  [mV]     [II]  47
# 2          2  500     5000      1      None  00:00:23  [mV]     [II]  41
# 3          3  500     5000      1      None  00:00:23  [mV]     [II]  68
# 4          4  500     5000      1      None  00:00:23  [mV]     [II]  41
# ...      ...  ...      ...    ...       ...       ...   ...      ...  ..
# 23945  10244  500     5000      1      None  00:00:23  [mV]     [II]  71
# 23946  10244  500     5000      1      None  00:00:23  [mV]     [II]  71
# 23947  10244  500     5000      1      None  00:00:23  [mV]     [II]  71
# 23948  10245  500     5000      1      None  00:00:24  [mV]     [II]  67
# 23949  10245  500     5000      1      None  00:00:24  [mV]     [II]  67
#
#           Sex                   Dx       Rx       Hx       Sx arquivos  \
# 0      Female  426177001,164934002  Unknown  Unknown  Unknown  JS08419
# 1      Female            426177001  Unknown  Unknown  Unknown  JS04442
# 2      Female            426177001  Unknown  Unknown  Unknown  JS00992
# 3      Female            427084000  Unknown  Unknown  Unknown  JS02338
# 4      Female            426177001  Unknown  Unknown  Unknown  JS01381
# ...       ...                  ...      ...      ...      ...      ...
# 23945  Female            426177001  Unknown  Unknown  Unknown  JS00117
# 23946  Female             39732003  Unknown  Unknown  Unknown  JS00117
# 23947  Female            428750005  Unknown  Unknown  Unknown  JS00117
# 23948  Female            426177001  Unknown  Unknown  Unknown  JS03916
# 23949  Female            164934002  Unknown  Unknown  Unknown  JS03916
#
#                        base
# 0      WFDB_ChapmanShaoxing
# 1      WFDB_ChapmanShaoxing
# 2      WFDB_ChapmanShaoxing
# 3      WFDB_ChapmanShaoxing
# 4      WFDB_ChapmanShaoxing
# ...                     ...
# 23945  WFDB_ChapmanShaoxing
# 23946  WFDB_ChapmanShaoxing
# 23947  WFDB_ChapmanShaoxing
# 23948  WFDB_ChapmanShaoxing
# 23949  WFDB_ChapmanShaoxing
#
# [23950 rows x 16 columns]

# %%
for x in range(len(df)):
    if len(df.loc[x]['Dx'].split(',')) > 1:
        df = df.drop(x)

# %%
df
# Out:
#        index   fs  sig_len  n_sig base_date base_time units sig_name Age  \
# 1          1  500     5000      1      None  00:00:24  [mV]     [II]  47
# 2          2  500     5000      1      None  00:00:23  [mV]     [II]  41
# 3          3  500     5000      1      None  00:00:23  [mV]     [II]  68
# 4          4  500     5000      1      None  00:00:23  [mV]     [II]  41
# 5          5  500     5000      1      None  00:00:23  [mV]     [II]  70
# ...      ...  ...      ...    ...       ...       ...   ...      ...  ..
# 23945  10244  500     5000      1      None  00:00:23  [mV]     [II]  71
# 23946  10244  500     5000      1      None  00:00:23  [mV]     [II]  71
# 23947  10244  500     5000      1      None  00:00:23  [mV]     [II]  71
# 23948  10245  500     5000      1      None  00:00:24  [mV]     [II]  67
# 23949  10245  500     5000      1      None  00:00:24  [mV]     [II]  67
#
#           Sex         Dx       Rx       Hx       Sx arquivos  \
# 1      Female  426177001  Unknown  Unknown  Unknown  JS04442
# 2      Female  426177001  Unknown  Unknown  Unknown  JS00992
# 3      Female  427084000  Unknown  Unknown  Unknown  JS02338
# 4      Female  426177001  Unknown  Unknown  Unknown  JS01381
# 5        Male  426177001  Unknown  Unknown  Unknown  JS02487
# ...       ...        ...      ...      ...      ...      ...
# 23945  Female  426177001  Unknown  Unknown  Unknown  JS00117
# 23946  Female   39732003  Unknown  Unknown  Unknown  JS00117
# 23947  Female  428750005  Unknown  Unknown  Unknown  JS00117
# 23948  Female  426177001  Unknown  Unknown  Unknown  JS03916
# 23949  Female  164934002  Unknown  Unknown  Unknown  JS03916
#
#                        base
# 1      WFDB_ChapmanShaoxing
# 2      WFDB_ChapmanShaoxing
# 3      WFDB_ChapmanShaoxing
# 4      WFDB_ChapmanShaoxing
# 5      WFDB_ChapmanShaoxing
# ...                     ...
# 23945  WFDB_ChapmanShaoxing
# 23946  WFDB_ChapmanShaoxing
# 23947  WFDB_ChapmanShaoxing
# 23948  WFDB_ChapmanShaoxing
# 23949  WFDB_ChapmanShaoxing
#
# [18844 rows x 16 columns]
